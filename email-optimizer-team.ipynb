# %%
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.conditions import MaxMessageTermination, TextMentionTermination
from autogen_agentchat.ui import Console
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
model = OpenAIChatCompletionClient(model="gpt-4o-mini")

clarity_agent = AssistantAgent(
    "ClarityAgent",
    model_client=model,
    system_message="""You are an expert editor focused on clarity and simplicity.
            Your job is to eliminate ambiguity, redundancy, and make every sentence crisp and clear.
            Don't worry about persuasion or tone — just make the message easy to read and understand.""",
)

tone_agent = AssistantAgent(
    "ToneAgent",
    model_client=model,
    system_message="""You are a communication coach focused on emotional tone and professionalism.
            Your job is to make the email sound warm, confident, and human — while staying professional
            and appropriate for the audience. Improve the emotional resonance, polish the phrasing,
            and adjust any words that may come off as stiff, cold, or overly casual.""",
)

persuasion_agent = AssistantAgent(
    "PersuasionAgent",
    model_client=model,
    system_message="""You are a persuasion expert trained in marketing, behavioral psychology,
            and copywriting. Your job is to enhance the email's persuasive power: improve call to action, structure arguments, and emphasize benefits. Remove weak or passive language.""",
)

synthesizer_agent = AssistantAgent(
    "SynthesizerAgent",
    model_client=model,
    system_message="""You are an advanced email-writing specialist. Your role is to read all
            prior agent responses and revisions, and then **synthesize the best ideas** into a unified,
            polished draft of the email. Focus on: Integrating clarity, tone, and persuasion improvements;
            Ensuring coherence, fluency, and a natural voice; Creating a version that feels professional,
            effective, and readable.""",
)

critic_agent = AssistantAgent(
    "CriticAgent",
    model_client=model,
    system_message="""You are an email quality evaluator. Your job is to perform a final review
            of the synthesized email and determine if it meets professional standards. Review the email for:
            Clarity and flow, appropriate professional tone, effective call-to-action, and overall coherence.
            Be constructive but decisive. If the email has major flaws (unclear message, unprofessional tone,
            or missing key elements), provide ONE specific improvement suggestion. If the email meets professional standards and communicates effectively, respond with 'The email meets professional standards.' followed by `TERMINATE` on a new line. You should only approve emails that are perfect enough for professional use, dont settle.""",
)

# %%
text_termination = TextMentionTermination("TERMINATE")
max_messages_termination = MaxMessageTermination(max_messages=30)

termination_condition = text_termination | max_messages_termination

# %%
team = RoundRobinGroupChat(
    participants=[
        clarity_agent,
        tone_agent,
        persuasion_agent,
        synthesizer_agent,
        critic_agent,
    ],
    termination_condition=termination_condition,
)

await Console(
    team.run_stream(
        task="Hi! Im hungry, buy me lunch and invest in my business. Thanks."
    )
)
# Out:
# ---------- TextMessage (user) ----------
# Hi! Im hungry, buy me lunch and invest in my business. Thanks.
# ---------- TextMessage (ClarityAgent) ----------
# Hi! I'm hungry. Please buy me lunch and invest in my business. Thanks.
# ---------- TextMessage (ToneAgent) ----------
# Subject: A Quick Favor
#
# Hi [Recipient's Name],
#
# I hope this message finds you well!
#
# I wanted to reach out because I’m feeling a bit hungry today and would love to grab lunch if you’re available. It would be a great opportunity to catch up and share some exciting updates about my business. I’m also looking for support and guidance as I explore potential investment options.
#
# Thank you for considering this, and I look forward to hearing from you!
#
# Warm regards,
#
# [Your Name]
# ---------- TextMessage (PersuasionAgent) ----------
# Subject: Let's Connect Over Lunch and Business!
#
# Hi [Recipient's Name],
#
# I hope you’re doing well!
#
# I’m reaching out because I’d love to treat you to lunch—my treat! Not only will it be a great opportunity for us to reconnect, but I've also got some exciting updates about my business that I think you’ll find intriguing.
#
# As I explore possibilities for investment, your insights and support would be invaluable to me. Let's discuss how you can be part of this journey and the potential benefits it could bring us both.
#
# Can we set a time to meet? I’m eager to share my vision with you!
#
# Thank you for considering this. Looking forward to hearing back from you soon!
#
# Best,
# [Your Name]
#
# ---------- TextMessage (SynthesizerAgent) ----------
# Subject: Let’s Connect Over Lunch and Business!
#
# Hi [Recipient's Name],
#
# I hope this message finds you well!
#
# I wanted to reach out and see if you’d be interested in joining me for lunch. I’d love to treat you, and it would be a wonderful opportunity for us to catch up. I have some exciting updates about my business that I think you'll find intriguing.
#
# As I explore potential investment options, your insights and support would mean a lot to me. I believe that discussing this over lunch could lead to some valuable ideas for both of us.
#
# Can we set a time to meet? I’m eager to share my vision and explore how you could be a part of this journey.
#
# Thank you for considering this. I look forward to hearing from you soon!
#
# Best,
# [Your Name]
# ---------- TextMessage (CriticAgent) ----------
# The email meets professional standards.
# TERMINATE
# TaskResult(messages=[TextMessage(id='a4648c61-626c-4549-bdca-6e56f39bbe3e', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 9, 24, 9, 31, 19, 750205, tzinfo=datetime.timezone.utc), content='Hi! Im hungry, buy me lunch and invest in my business. Thanks.', type='TextMessage'), TextMessage(id='11c1a6d9-7db4-4f07-8f74-5fd6a09f7a62', source='ClarityAgent', models_usage=RequestUsage(prompt_tokens=75, completion_tokens=17), metadata={}, created_at=datetime.datetime(2025, 9, 24, 9, 31, 21, 993685, tzinfo=datetime.timezone.utc), content="Hi! I'm hungry. Please buy me lunch and invest in my business. Thanks.", type='TextMessage'), TextMessage(id='dd687787-06bd-4306-a8bd-d2e38f64ee61', source='ToneAgent', models_usage=RequestUsage(prompt_tokens=120, completion_tokens=100), metadata={}, created_at=datetime.datetime(2025, 9, 24, 9, 31, 25, 213939, tzinfo=datetime.timezone.utc), content="Subject: A Quick Favor\n\nHi [Recipient's Name],\n\nI hope this message finds you well! \n\nI wanted to reach out because I’m feeling a bit hungry today and would love to grab lunch if you’re available. It would be a great opportunity to catch up and share some exciting updates about my business. I’m also looking for support and guidance as I explore potential investment options.\n\nThank you for considering this, and I look forward to hearing from you!\n\nWarm regards,\n\n[Your Name]", type='TextMessage'), TextMessage(id='614db259-39f1-4f4e-98d7-87cec9903f16', source='PersuasionAgent', models_usage=RequestUsage(prompt_tokens=206, completion_tokens=151), metadata={}, created_at=datetime.datetime(2025, 9, 24, 9, 31, 28, 673969, tzinfo=datetime.timezone.utc), content="Subject: Let's Connect Over Lunch and Business!\n\nHi [Recipient's Name],\n\nI hope you’re doing well! \n\nI’m reaching out because I’d love to treat you to lunch—my treat! Not only will it be a great opportunity for us to reconnect, but I've also got some exciting updates about my business that I think you’ll find intriguing. \n\nAs I explore possibilities for investment, your insights and support would be invaluable to me. Let's discuss how you can be part of this journey and the potential benefits it could bring us both. \n\nCan we set a time to meet? I’m eager to share my vision with you!\n\nThank you for considering this. Looking forward to hearing back from you soon!\n\nBest,  \n[Your Name]  \n", type='TextMessage'), TextMessage(id='0a872d7f-9b0c-4d87-a16e-71512dfd6d22', source='SynthesizerAgent', models_usage=RequestUsage(prompt_tokens=401, completion_tokens=162), metadata={}, created_at=datetime.datetime(2025, 9, 24, 9, 31, 32, 215853, tzinfo=datetime.timezone.utc), content="Subject: Let’s Connect Over Lunch and Business!\n\nHi [Recipient's Name],\n\nI hope this message finds you well!\n\nI wanted to reach out and see if you’d be interested in joining me for lunch. I’d love to treat you, and it would be a wonderful opportunity for us to catch up. I have some exciting updates about my business that I think you'll find intriguing.\n\nAs I explore potential investment options, your insights and support would mean a lot to me. I believe that discussing this over lunch could lead to some valuable ideas for both of us.\n\nCan we set a time to meet? I’m eager to share my vision and explore how you could be a part of this journey.\n\nThank you for considering this. I look forward to hearing from you soon!\n\nBest,  \n[Your Name]", type='TextMessage'), TextMessage(id='ff37f73e-80c2-4b0a-9b3c-f0ead562ef65', source='CriticAgent', models_usage=RequestUsage(prompt_tokens=624, completion_tokens=10), metadata={}, created_at=datetime.datetime(2025, 9, 24, 9, 31, 33, 419676, tzinfo=datetime.timezone.utc), content='The email meets professional standards.  \nTERMINATE', type='TextMessage')], stop_reason="Text 'TERMINATE' mentioned")
